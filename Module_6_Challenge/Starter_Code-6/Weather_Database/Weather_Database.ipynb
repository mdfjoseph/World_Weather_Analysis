# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 789

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?id=524901&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities.  
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                        "Current Description": city_description})
        
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kununurra
# Processing Record 2 of Set 1 | souillac
# Processing Record 3 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | mangai
# Processing Record 6 of Set 1 | kaisiadorys
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | kristinehamn
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | kineta
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | ellsworth
# Processing Record 16 of Set 1 | asau
# Processing Record 17 of Set 1 | petrokamenskoye
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | khatanga
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | gouyave
# Processing Record 23 of Set 1 | timmins
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 26 of Set 1 | pacific grove
# Processing Record 27 of Set 1 | rahimatpur
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | joshimath
# Processing Record 30 of Set 1 | bredasdorp
# Processing Record 31 of Set 1 | cabo san lucas
# Processing Record 32 of Set 1 | anqiu
# Processing Record 33 of Set 1 | port blair
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | hermanus
# Processing Record 36 of Set 1 | atambua
# Processing Record 37 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 1 | vila do maio
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | broken hill
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | calbuco
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | yar-sale
# Processing Record 47 of Set 1 | talnakh
# Processing Record 48 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | indian harbour beach
# Processing Record 1 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 2 | san isidro
# Processing Record 3 of Set 2 | san blas
# Processing Record 4 of Set 2 | sur
# Processing Record 5 of Set 2 | hilo
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | naron
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | rio gallegos
# Processing Record 12 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 2 | sakhon nakhon
# Processing Record 14 of Set 2 | nome
# Processing Record 15 of Set 2 | redkino
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | bubaque
# Processing Record 18 of Set 2 | hervey bay
# Processing Record 19 of Set 2 | aklavik
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | safwah
# City not found. Skipping...
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | chuy
# Processing Record 24 of Set 2 | yukamenskoye
# Processing Record 25 of Set 2 | chicama
# Processing Record 26 of Set 2 | bluefields
# Processing Record 27 of Set 2 | zacatepec
# Processing Record 28 of Set 2 | spring valley
# Processing Record 29 of Set 2 | superior
# Processing Record 30 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 2 | valladolid
# Processing Record 32 of Set 2 | kerouane
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | roald
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | correntina
# Processing Record 37 of Set 2 | qianguo
# Processing Record 38 of Set 2 | comodoro rivadavia
# Processing Record 39 of Set 2 | guatire
# Processing Record 40 of Set 2 | meybod
# Processing Record 41 of Set 2 | wum
# Processing Record 42 of Set 2 | hovd
# Processing Record 43 of Set 2 | terrace
# Processing Record 44 of Set 2 | nikolskoye
# Processing Record 45 of Set 2 | praya
# Processing Record 46 of Set 2 | puerto del rosario
# Processing Record 47 of Set 2 | waipawa
# Processing Record 48 of Set 2 | zhigansk
# Processing Record 49 of Set 2 | vestmanna
# Processing Record 50 of Set 2 | henties bay
# Processing Record 1 of Set 3 | kutum
# Processing Record 2 of Set 3 | luderitz
# Processing Record 3 of Set 3 | kapaa
# Processing Record 4 of Set 3 | meulaboh
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | antalaha
# Processing Record 7 of Set 3 | kodiak
# Processing Record 8 of Set 3 | krasnyy chikoy
# Processing Record 9 of Set 3 | shingu
# Processing Record 10 of Set 3 | mataura
# Processing Record 11 of Set 3 | creel
# Processing Record 12 of Set 3 | lata
# Processing Record 13 of Set 3 | la ronge
# Processing Record 14 of Set 3 | smithers
# Processing Record 15 of Set 3 | longyearbyen
# Processing Record 16 of Set 3 | thai binh
# Processing Record 17 of Set 3 | fukue
# Processing Record 18 of Set 3 | hithadhoo
# Processing Record 19 of Set 3 | the valley
# Processing Record 20 of Set 3 | baruun-urt
# Processing Record 21 of Set 3 | alice springs
# Processing Record 22 of Set 3 | port augusta
# Processing Record 23 of Set 3 | gaspe
# Processing Record 24 of Set 3 | paamiut
# Processing Record 25 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 3 | carnarvon
# Processing Record 28 of Set 3 | guarapari
# Processing Record 29 of Set 3 | iqaluit
# Processing Record 30 of Set 3 | puerto baquerizo moreno
# Processing Record 31 of Set 3 | pittsburg
# Processing Record 32 of Set 3 | mount gambier
# Processing Record 33 of Set 3 | ibra
# Processing Record 34 of Set 3 | uyar
# Processing Record 35 of Set 3 | cape town
# Processing Record 36 of Set 3 | los llanos de aridane
# Processing Record 37 of Set 3 | shakhtinsk
# Processing Record 38 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | kirakira
# Processing Record 41 of Set 3 | dikson
# Processing Record 42 of Set 3 | bodden town
# Processing Record 43 of Set 3 | hobyo
# Processing Record 44 of Set 3 | bocas del toro
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | saint george
# Processing Record 48 of Set 3 | nagahama
# Processing Record 49 of Set 3 | norman wells
# Processing Record 50 of Set 3 | upernavik
# Processing Record 1 of Set 4 | kokopo
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | codrington
# Processing Record 4 of Set 4 | praia da vitoria
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | nurota
# Processing Record 7 of Set 4 | lagos
# Processing Record 8 of Set 4 | verkhoyansk
# Processing Record 9 of Set 4 | salisbury
# Processing Record 10 of Set 4 | cabo rojo
# Processing Record 11 of Set 4 | willowmore
# Processing Record 12 of Set 4 | harper
# Processing Record 13 of Set 4 | whitehorse
# Processing Record 14 of Set 4 | guerrero negro
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | sorland
# Processing Record 18 of Set 4 | vardo
# Processing Record 19 of Set 4 | chake chake
# Processing Record 20 of Set 4 | khani
# Processing Record 21 of Set 4 | kaitangata
# Processing Record 22 of Set 4 | caravelas
# Processing Record 23 of Set 4 | port moresby
# Processing Record 24 of Set 4 | kwinana
# Processing Record 25 of Set 4 | udachnyy
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | karaton
# Processing Record 28 of Set 4 | alofi
# Processing Record 29 of Set 4 | manoharpur
# Processing Record 30 of Set 4 | san matias
# Processing Record 31 of Set 4 | bethel
# Processing Record 32 of Set 4 | abu samrah
# Processing Record 33 of Set 4 | lhuntshi
# City not found. Skipping...
# Processing Record 34 of Set 4 | port lincoln
# Processing Record 35 of Set 4 | bathsheba
# Processing Record 36 of Set 4 | maceio
# Processing Record 37 of Set 4 | catamarca
# Processing Record 38 of Set 4 | saldanha
# Processing Record 39 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 4 | homer
# Processing Record 41 of Set 4 | hornepayne
# Processing Record 42 of Set 4 | kahului
# Processing Record 43 of Set 4 | oranjemund
# Processing Record 44 of Set 4 | opaka
# Processing Record 45 of Set 4 | tongren
# Processing Record 46 of Set 4 | ucluelet
# Processing Record 47 of Set 4 | wuwei
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 4 | huarmey
# Processing Record 1 of Set 5 | kanungu
# Processing Record 2 of Set 5 | nemuro
# Processing Record 3 of Set 5 | marsh harbour
# Processing Record 4 of Set 5 | baripada
# Processing Record 5 of Set 5 | puerto escondido
# Processing Record 6 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 7 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 5 | teluk nibung
# Processing Record 9 of Set 5 | fortuna
# Processing Record 10 of Set 5 | castro
# Processing Record 11 of Set 5 | ranong
# Processing Record 12 of Set 5 | balgazyn
# Processing Record 13 of Set 5 | cayenne
# Processing Record 14 of Set 5 | salalah
# Processing Record 15 of Set 5 | banff
# Processing Record 16 of Set 5 | tuatapere
# Processing Record 17 of Set 5 | saint anthony
# Processing Record 18 of Set 5 | ponta delgada
# Processing Record 19 of Set 5 | puerto ayora
# Processing Record 20 of Set 5 | moerai
# Processing Record 21 of Set 5 | saskylakh
# Processing Record 22 of Set 5 | avera
# Processing Record 23 of Set 5 | el ejido
# Processing Record 24 of Set 5 | woodward
# Processing Record 25 of Set 5 | shatsk
# Processing Record 26 of Set 5 | ancud
# Processing Record 27 of Set 5 | bara
# Processing Record 28 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 5 | bengkulu
# Processing Record 30 of Set 5 | sao jose da coroa grande
# Processing Record 31 of Set 5 | oudtshoorn
# Processing Record 32 of Set 5 | vysokogornyy
# Processing Record 33 of Set 5 | oussouye
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | la algaba
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | torremolinos
# Processing Record 38 of Set 5 | fort nelson
# Processing Record 39 of Set 5 | new iberia
# Processing Record 40 of Set 5 | nuuk
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | grass valley
# Processing Record 43 of Set 5 | provideniya
# Processing Record 44 of Set 5 | sarkand
# Processing Record 45 of Set 5 | verkhnetulomskiy
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | villa corzo
# Processing Record 48 of Set 5 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 49 of Set 5 | ngunguru
# Processing Record 50 of Set 5 | sao joao da barra
# Processing Record 1 of Set 6 | killarney
# Processing Record 2 of Set 6 | harindanga
# Processing Record 3 of Set 6 | bambous virieux
# Processing Record 4 of Set 6 | namwala
# Processing Record 5 of Set 6 | mehamn
# Processing Record 6 of Set 6 | strezhevoy
# Processing Record 7 of Set 6 | shenzhen
# Processing Record 8 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 6 | tessalit
# Processing Record 10 of Set 6 | port hardy
# Processing Record 11 of Set 6 | tynda
# Processing Record 12 of Set 6 | padang
# Processing Record 13 of Set 6 | umm lajj
# Processing Record 14 of Set 6 | atasu
# Processing Record 15 of Set 6 | kenai
# Processing Record 16 of Set 6 | blitar
# Processing Record 17 of Set 6 | laguna
# Processing Record 18 of Set 6 | loa janan
# Processing Record 19 of Set 6 | key west
# Processing Record 20 of Set 6 | mar del plata
# Processing Record 21 of Set 6 | nabire
# Processing Record 22 of Set 6 | lagoa
# Processing Record 23 of Set 6 | san quintin
# Processing Record 24 of Set 6 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 6 | krasnyy yar
# Processing Record 26 of Set 6 | brae
# Processing Record 27 of Set 6 | fare
# Processing Record 28 of Set 6 | port elizabeth
# Processing Record 29 of Set 6 | torbay
# Processing Record 30 of Set 6 | batagay
# Processing Record 31 of Set 6 | nangomba
# Processing Record 32 of Set 6 | tilichiki
# Processing Record 33 of Set 6 | aksarka
# Processing Record 34 of Set 6 | hirara
# Processing Record 35 of Set 6 | ikryanoye
# Processing Record 36 of Set 6 | constitucion
# Processing Record 37 of Set 6 | camana
# Processing Record 38 of Set 6 | jaguaquara
# Processing Record 39 of Set 6 | kemijarvi
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | santiago del estero
# Processing Record 42 of Set 6 | berlevag
# Processing Record 43 of Set 6 | boguchany
# Processing Record 44 of Set 6 | sivaki
# Processing Record 45 of Set 6 | ndola
# Processing Record 46 of Set 6 | dudinka
# Processing Record 47 of Set 6 | herzele
# Processing Record 48 of Set 6 | abu dhabi
# Processing Record 49 of Set 6 | utica
# Processing Record 50 of Set 6 | rockland
# Processing Record 1 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 7 | rawson
# Processing Record 3 of Set 7 | ambilobe
# Processing Record 4 of Set 7 | adrar
# Processing Record 5 of Set 7 | xuanzhou
# Processing Record 6 of Set 7 | witu
# Processing Record 7 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 8 of Set 7 | soyo
# Processing Record 9 of Set 7 | vila velha
# Processing Record 10 of Set 7 | russell
# Processing Record 11 of Set 7 | walvis bay
# Processing Record 12 of Set 7 | tabou
# Processing Record 13 of Set 7 | takoradi
# Processing Record 14 of Set 7 | muros
# Processing Record 15 of Set 7 | aljezur
# Processing Record 16 of Set 7 | dzhebariki-khaya
# Processing Record 17 of Set 7 | carndonagh
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | zhuhai
# Processing Record 20 of Set 7 | samarai
# Processing Record 21 of Set 7 | lebanon
# Processing Record 22 of Set 7 | portland
# Processing Record 23 of Set 7 | nanortalik
# Processing Record 24 of Set 7 | tambun
# Processing Record 25 of Set 7 | houma
# Processing Record 26 of Set 7 | qaanaaq
# Processing Record 27 of Set 7 | kosa
# Processing Record 28 of Set 7 | angoche
# Processing Record 29 of Set 7 | plettenberg bay
# Processing Record 30 of Set 7 | ilulissat
# Processing Record 31 of Set 7 | corrente
# Processing Record 32 of Set 7 | safaga
# Processing Record 33 of Set 7 | san-pedro
# Processing Record 34 of Set 7 | nishihara
# Processing Record 35 of Set 7 | giulianova
# Processing Record 36 of Set 7 | chokurdakh
# Processing Record 37 of Set 7 | vestmannaeyjar
# Processing Record 38 of Set 7 | ikwiriri
# Processing Record 39 of Set 7 | victoria
# Processing Record 40 of Set 7 | merauke
# Processing Record 41 of Set 7 | kampene
# Processing Record 42 of Set 7 | winnemucca
# Processing Record 43 of Set 7 | lichuan
# Processing Record 44 of Set 7 | challans
# Processing Record 45 of Set 7 | san carlos de bariloche
# Processing Record 46 of Set 7 | vostok
# Processing Record 47 of Set 7 | nadym
# Processing Record 48 of Set 7 | itarema
# Processing Record 49 of Set 7 | narsaq
# Processing Record 50 of Set 7 | algodones
# Processing Record 1 of Set 8 | jalu
# Processing Record 2 of Set 8 | katsuura
# Processing Record 3 of Set 8 | alushta
# Processing Record 4 of Set 8 | caramay
# Processing Record 5 of Set 8 | zverinogolovskoye
# Processing Record 6 of Set 8 | colquechaca
# Processing Record 7 of Set 8 | stephenville
# Processing Record 8 of Set 8 | bam
# Processing Record 9 of Set 8 | ostrovnoy
# Processing Record 10 of Set 8 | sungaipenuh
# Processing Record 11 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | sortavala
# Processing Record 14 of Set 8 | campiglia marittima
# Processing Record 15 of Set 8 | macas
# Processing Record 16 of Set 8 | havelock
# Processing Record 17 of Set 8 | kerema
# Processing Record 18 of Set 8 | melo
# Processing Record 19 of Set 8 | pisco
# Processing Record 20 of Set 8 | aksu
# Processing Record 21 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 8 | kavieng
# Processing Record 23 of Set 8 | morant bay
# Processing Record 24 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 25 of Set 8 | caucasia
# Processing Record 26 of Set 8 | mandalgovi
# Processing Record 27 of Set 8 | usinsk
# Processing Record 28 of Set 8 | biak
# Processing Record 29 of Set 8 | el sauzal
# Processing Record 30 of Set 8 | safidon
# Processing Record 31 of Set 8 | cherskiy
# Processing Record 32 of Set 8 | richards bay
# Processing Record 33 of Set 8 | ola
# Processing Record 34 of Set 8 | mersin
# Processing Record 35 of Set 8 | jieshi
# Processing Record 36 of Set 8 | vallenar
# Processing Record 37 of Set 8 | kars
# Processing Record 38 of Set 8 | zhangye
# Processing Record 39 of Set 8 | sioux lookout
# Processing Record 40 of Set 8 | areia branca
# Processing Record 41 of Set 8 | deputatskiy
# Processing Record 42 of Set 8 | rio muerto
# Processing Record 43 of Set 8 | callaguip
# Processing Record 44 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 8 | nhulunbuy
# Processing Record 46 of Set 8 | lompoc
# Processing Record 47 of Set 8 | yumen
# Processing Record 48 of Set 8 | sao jose do belmonte
# Processing Record 49 of Set 8 | saint-joseph
# Processing Record 50 of Set 8 | arman
# Processing Record 1 of Set 9 | koksovyy
# Processing Record 2 of Set 9 | sturgis
# Processing Record 3 of Set 9 | dalbandin
# Processing Record 4 of Set 9 | gerash
# Processing Record 5 of Set 9 | labuan
# Processing Record 6 of Set 9 | tevaitoa
# Processing Record 7 of Set 9 | grindavik
# Processing Record 8 of Set 9 | kirovskiy
# Processing Record 9 of Set 9 | shreveport
# Processing Record 10 of Set 9 | ahipara
# Processing Record 11 of Set 9 | puerto narino
# Processing Record 12 of Set 9 | debre tabor
# Processing Record 13 of Set 9 | rocha
# Processing Record 14 of Set 9 | garowe
# Processing Record 15 of Set 9 | aswan
# Processing Record 16 of Set 9 | san cristobal
# Processing Record 17 of Set 9 | birjand
# Processing Record 18 of Set 9 | sawakin
# Processing Record 19 of Set 9 | hofn
# Processing Record 20 of Set 9 | margate
# Processing Record 21 of Set 9 | poya
# Processing Record 22 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 9 | atar
# Processing Record 24 of Set 9 | nador
# Processing Record 25 of Set 9 | isla vista
# Processing Record 26 of Set 9 | siguiri
# Processing Record 27 of Set 9 | calatayud
# Processing Record 28 of Set 9 | san felipe
# Processing Record 29 of Set 9 | araouane
# Processing Record 30 of Set 9 | beberibe
# Processing Record 31 of Set 9 | pimenta bueno
# Processing Record 32 of Set 9 | namatanai
# Processing Record 33 of Set 9 | myski
# Processing Record 34 of Set 9 | berdychiv
# Processing Record 35 of Set 9 | kassala
# Processing Record 36 of Set 9 | mareeba
# Processing Record 37 of Set 9 | khuzhir
# Processing Record 38 of Set 9 | saint-pierre
# Processing Record 39 of Set 9 | dahuk
# Processing Record 40 of Set 9 | belle fourche
# Processing Record 41 of Set 9 | solnechnyy
# Processing Record 42 of Set 9 | verkhnyaya inta
# Processing Record 43 of Set 9 | geraldton
# Processing Record 44 of Set 9 | yerbogachen
# Processing Record 45 of Set 9 | jaisalmer
# Processing Record 46 of Set 9 | kapoeta
# Processing Record 47 of Set 9 | copiapo
# Processing Record 48 of Set 9 | wangaratta
# Processing Record 49 of Set 9 | ixtapa
# Processing Record 50 of Set 9 | norwich
# Processing Record 1 of Set 10 | abong mbang
# Processing Record 2 of Set 10 | gubkinskiy
# Processing Record 3 of Set 10 | talara
# Processing Record 4 of Set 10 | joensuu
# Processing Record 5 of Set 10 | kesinga
# Processing Record 6 of Set 10 | iskenderun
# Processing Record 7 of Set 10 | sept-iles
# Processing Record 8 of Set 10 | miri
# Processing Record 9 of Set 10 | lukiv
# Processing Record 10 of Set 10 | reconquista
# Processing Record 11 of Set 10 | riyadh
# Processing Record 12 of Set 10 | miraflores
# Processing Record 13 of Set 10 | batticaloa
# Processing Record 14 of Set 10 | santa isabel do rio negro
# Processing Record 15 of Set 10 | nokaneng
# Processing Record 16 of Set 10 | tecolutilla
# Processing Record 17 of Set 10 | portobelo
# Processing Record 18 of Set 10 | senanga
# Processing Record 19 of Set 10 | fayaoue
# Processing Record 20 of Set 10 | nioro
# Processing Record 21 of Set 10 | chokwe
# Processing Record 22 of Set 10 | cheuskiny
# City not found. Skipping...
# Processing Record 23 of Set 10 | nouadhibou
# Processing Record 24 of Set 10 | grand gaube
# Processing Record 25 of Set 10 | mahajanga
# Processing Record 26 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 10 | tasiilaq
# Processing Record 28 of Set 10 | monte alegre
# Processing Record 29 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 30 of Set 10 | bilibino
# Processing Record 31 of Set 10 | port-gentil
# Processing Record 32 of Set 10 | shakawe
# Processing Record 33 of Set 10 | tonj
# Processing Record 34 of Set 10 | kualakapuas
# Processing Record 35 of Set 10 | presidente medici
# Processing Record 36 of Set 10 | maniitsoq
# Processing Record 37 of Set 10 | chipurupalle
# Processing Record 38 of Set 10 | andra
# Processing Record 39 of Set 10 | whangamata
# Processing Record 40 of Set 10 | kimberley
# Processing Record 41 of Set 10 | poronaysk
# Processing Record 42 of Set 10 | ambulu
# Processing Record 43 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 10 | almora
# Processing Record 45 of Set 10 | high level
# Processing Record 46 of Set 10 | garissa
# Processing Record 47 of Set 10 | isoka
# Processing Record 48 of Set 10 | ozernovskiy
# Processing Record 49 of Set 10 | igrim
# Processing Record 50 of Set 10 | kabo
# Processing Record 1 of Set 11 | dubbo
# Processing Record 2 of Set 11 | lovozero
# Processing Record 3 of Set 11 | manta
# Processing Record 4 of Set 11 | katherine
# Processing Record 5 of Set 11 | beloha
# Processing Record 6 of Set 11 | makakilo city
# Processing Record 7 of Set 11 | corinto
# Processing Record 8 of Set 11 | bajo baudo
# City not found. Skipping...
# Processing Record 9 of Set 11 | brazzaville
# Processing Record 10 of Set 11 | erenhot
# Processing Record 11 of Set 11 | gemena
# Processing Record 12 of Set 11 | asheboro
# Processing Record 13 of Set 11 | valdivia
# Processing Record 14 of Set 11 | san patricio
# Processing Record 15 of Set 11 | twentynine palms
# Processing Record 16 of Set 11 | lincoln
# Processing Record 17 of Set 11 | semey
# Processing Record 18 of Set 11 | kota bahru
# Processing Record 19 of Set 11 | kresttsy
# Processing Record 20 of Set 11 | kozan
# Processing Record 21 of Set 11 | novyy svit
# Processing Record 22 of Set 11 | yenagoa
# Processing Record 23 of Set 11 | mecca
# Processing Record 24 of Set 11 | mount isa
# Processing Record 25 of Set 11 | sao miguel do araguaia
# Processing Record 26 of Set 11 | zaysan
# Processing Record 27 of Set 11 | jian
# Processing Record 28 of Set 11 | methala
# Processing Record 29 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 11 | kajiado
# Processing Record 31 of Set 11 | lazaro cardenas
# Processing Record 32 of Set 11 | saquena
# Processing Record 33 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 34 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 11 | rantauprapat
# Processing Record 36 of Set 11 | koygorodok
# Processing Record 37 of Set 11 | tual
# Processing Record 38 of Set 11 | te anau
# Processing Record 39 of Set 11 | normandin
# Processing Record 40 of Set 11 | yalchiki
# City not found. Skipping...
# Processing Record 41 of Set 11 | clyde river
# Processing Record 42 of Set 11 | najran
# Processing Record 43 of Set 11 | englewood
# Processing Record 44 of Set 11 | yeniseysk
# Processing Record 45 of Set 11 | seymchan
# Processing Record 46 of Set 11 | chara
# Processing Record 47 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 48 of Set 11 | vitim
# Processing Record 49 of Set 11 | bridgend
# Processing Record 50 of Set 11 | katunki
# City not found. Skipping...
# Processing Record 1 of Set 12 | vodyane
# Processing Record 2 of Set 12 | helong
# Processing Record 3 of Set 12 | goderich
# Processing Record 4 of Set 12 | watrous
# Processing Record 5 of Set 12 | ginda
# Processing Record 6 of Set 12 | aguas vermelhas
# Processing Record 7 of Set 12 | nayoro
# Processing Record 8 of Set 12 | bonavista
# Processing Record 9 of Set 12 | sitka
# Processing Record 10 of Set 12 | suez
# Processing Record 11 of Set 12 | arlit
# Processing Record 12 of Set 12 | sambava
# Processing Record 13 of Set 12 | ksenyevka
# City not found. Skipping...
# Processing Record 14 of Set 12 | kitob
# Processing Record 15 of Set 12 | banjar
# Processing Record 16 of Set 12 | el alto
# Processing Record 17 of Set 12 | zakupne
# Processing Record 18 of Set 12 | burica
# City not found. Skipping...
# Processing Record 19 of Set 12 | nantucket
# Processing Record 20 of Set 12 | vila
# Processing Record 21 of Set 12 | westport
# Processing Record 22 of Set 12 | le port
# Processing Record 23 of Set 12 | honiara
# Processing Record 24 of Set 12 | mapiri
# Processing Record 25 of Set 12 | kampot
# Processing Record 26 of Set 12 | vangaindrano
# Processing Record 27 of Set 12 | antofagasta
# Processing Record 28 of Set 12 | svetlaya
# Processing Record 29 of Set 12 | periyakulam
# Processing Record 30 of Set 12 | bemidji
# Processing Record 31 of Set 12 | iskateley
# Processing Record 32 of Set 12 | tezu
# Processing Record 33 of Set 12 | mto wa mbu
# Processing Record 34 of Set 12 | baykit
# Processing Record 35 of Set 12 | derzhavinsk
# Processing Record 36 of Set 12 | hede
# Processing Record 37 of Set 12 | okha
# Processing Record 38 of Set 12 | bandarbeyla
# Processing Record 39 of Set 12 | waraseoni
# Processing Record 40 of Set 12 | metro
# Processing Record 41 of Set 12 | along
# Processing Record 42 of Set 12 | shugurovo
# Processing Record 43 of Set 12 | ulan-ude
# Processing Record 44 of Set 12 | maamba
# Processing Record 45 of Set 12 | fort saint james
# Processing Record 46 of Set 12 | puqi
# Processing Record 47 of Set 12 | port hedland
# Processing Record 48 of Set 12 | zitlala
# Processing Record 49 of Set 12 | ciego de avila
# Processing Record 50 of Set 12 | nanning
# Processing Record 1 of Set 13 | bozhou
# Processing Record 2 of Set 13 | romodanovo
# Processing Record 3 of Set 13 | uray
# Processing Record 4 of Set 13 | egvekinot
# Processing Record 5 of Set 13 | conakry
# Processing Record 6 of Set 13 | sola
# Processing Record 7 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 8 of Set 13 | davila
# Processing Record 9 of Set 13 | gladstone
# Processing Record 10 of Set 13 | yarada
# Processing Record 11 of Set 13 | bronnoysund
# Processing Record 12 of Set 13 | duldurga
# Processing Record 13 of Set 13 | carbonia
# Processing Record 14 of Set 13 | ntoum
# Processing Record 15 of Set 13 | sabang
# Processing Record 16 of Set 13 | champerico
# Processing Record 17 of Set 13 | itaituba
# Processing Record 18 of Set 13 | luoyang
# Processing Record 19 of Set 13 | oktyabrskiy
# Processing Record 20 of Set 13 | trois-rivieres
# Processing Record 21 of Set 13 | fenoarivo
# Processing Record 22 of Set 13 | parrita
# Processing Record 23 of Set 13 | jishou
# Processing Record 24 of Set 13 | veraval
# Processing Record 25 of Set 13 | moyale
# Processing Record 26 of Set 13 | sisimiut
# Processing Record 27 of Set 13 | tungkang
# City not found. Skipping...
# Processing Record 28 of Set 13 | camacha
# Processing Record 29 of Set 13 | glenwood springs
# Processing Record 30 of Set 13 | touros
# Processing Record 31 of Set 13 | hambantota
# Processing Record 32 of Set 13 | taltal
# Processing Record 33 of Set 13 | ningxiang
# Processing Record 34 of Set 13 | nogliki
# Processing Record 35 of Set 13 | cap malheureux
# Processing Record 36 of Set 13 | beringovskiy
# Processing Record 37 of Set 13 | qui nhon
# Processing Record 38 of Set 13 | yakeshi
# Processing Record 39 of Set 13 | ormara
# Processing Record 40 of Set 13 | vao
# Processing Record 41 of Set 13 | kilrush
# Processing Record 42 of Set 13 | evensk
# Processing Record 43 of Set 13 | mount pleasant
# Processing Record 44 of Set 13 | umea
# Processing Record 45 of Set 13 | san luis
# Processing Record 46 of Set 13 | belmonte
# Processing Record 47 of Set 13 | shellbrook
# Processing Record 48 of Set 13 | otjimbingwe
# Processing Record 49 of Set 13 | santo domingo
# Processing Record 50 of Set 13 | gilgit
# Processing Record 1 of Set 14 | iranshahr
# Processing Record 2 of Set 14 | shu
# Processing Record 3 of Set 14 | grimshaw
# Processing Record 4 of Set 14 | vasterhaninge
# Processing Record 5 of Set 14 | ewo
# Processing Record 6 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 14 | sabha
# Processing Record 8 of Set 14 | ligayan
# Processing Record 9 of Set 14 | mabaruma
# Processing Record 10 of Set 14 | dauphin
# Processing Record 11 of Set 14 | ayagoz
# Processing Record 12 of Set 14 | rancharia
# Processing Record 13 of Set 14 | benguela
# Processing Record 14 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 14 | jackson
# Processing Record 16 of Set 14 | fomboni
# Processing Record 17 of Set 14 | sao jose de ribamar
# Processing Record 18 of Set 14 | tiznit
# Processing Record 19 of Set 14 | craig
# Processing Record 20 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 21 of Set 14 | paris
# Processing Record 22 of Set 14 | glinde
# Processing Record 23 of Set 14 | beira
# Processing Record 24 of Set 14 | lasem
# Processing Record 25 of Set 14 | abonnema
# Processing Record 26 of Set 14 | ust-nera
# Processing Record 27 of Set 14 | san juan de la maguana
# Processing Record 28 of Set 14 | mariental
# Processing Record 29 of Set 14 | natal
# Processing Record 30 of Set 14 | faya
# Processing Record 31 of Set 14 | tukrah
# Processing Record 32 of Set 14 | kloulklubed
# Processing Record 33 of Set 14 | gravdal
# Processing Record 34 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 35 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 36 of Set 14 | shakiso
# Processing Record 37 of Set 14 | kisangani
# Processing Record 38 of Set 14 | ryotsu
# Processing Record 39 of Set 14 | price
# Processing Record 40 of Set 14 | aurillac
# Processing Record 41 of Set 14 | skibbereen
# Processing Record 42 of Set 14 | huejuquilla el alto
# Processing Record 43 of Set 14 | soe
# Processing Record 44 of Set 14 | kalmunai
# Processing Record 45 of Set 14 | xining
# Processing Record 46 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 47 of Set 14 | mbandaka
# Processing Record 48 of Set 14 | lyngseidet
# Processing Record 49 of Set 14 | ipubi
# Processing Record 50 of Set 14 | meadow lake
# Processing Record 1 of Set 15 | pilar
# Processing Record 2 of Set 15 | tokur
# Processing Record 3 of Set 15 | marinette
# Processing Record 4 of Set 15 | benghazi
# Processing Record 5 of Set 15 | pundaguitan
# Processing Record 6 of Set 15 | komsomolskiy
# Processing Record 7 of Set 15 | lavrentiya
# Processing Record 8 of Set 15 | pustoshka
# Processing Record 9 of Set 15 | alta floresta
# Processing Record 10 of Set 15 | oksfjord
# Processing Record 11 of Set 15 | lar gerd
# City not found. Skipping...
# Processing Record 12 of Set 15 | beyneu
# Processing Record 13 of Set 15 | tytuvenai
# Processing Record 14 of Set 15 | jiangyou
# Processing Record 15 of Set 15 | matara
# Processing Record 16 of Set 15 | florianopolis
# Processing Record 17 of Set 15 | reitz
# Processing Record 18 of Set 15 | okhotsk
# Processing Record 19 of Set 15 | ongandjera
# Processing Record 20 of Set 15 | lasa
# Processing Record 21 of Set 15 | yomitan
# City not found. Skipping...
# Processing Record 22 of Set 15 | verkhovazhye
# Processing Record 23 of Set 15 | esmeraldas
# Processing Record 24 of Set 15 | dali
# Processing Record 25 of Set 15 | afua
# Processing Record 26 of Set 15 | cascais
# Processing Record 27 of Set 15 | kropotkin
# Processing Record 28 of Set 15 | valparaiso
# Processing Record 29 of Set 15 | muli
# Processing Record 30 of Set 15 | rosetta
# Processing Record 31 of Set 15 | kudat
# Processing Record 32 of Set 15 | coihaique
# Processing Record 33 of Set 15 | falakata
# Processing Record 34 of Set 15 | yulara
# Processing Record 35 of Set 15 | alihe
# Processing Record 36 of Set 15 | adzhamka
# Processing Record 37 of Set 15 | rocky mountain house
# Processing Record 38 of Set 15 | saint-felicien
# Processing Record 39 of Set 15 | rawlins
# Processing Record 40 of Set 15 | minna
# Processing Record 41 of Set 15 | devyatka
# City not found. Skipping...
# Processing Record 42 of Set 15 | yurino
# Processing Record 43 of Set 15 | boralday
# Processing Record 44 of Set 15 | taoudenni
# Processing Record 45 of Set 15 | sedam
# Processing Record 46 of Set 15 | olot
# Processing Record 47 of Set 15 | varhaug
# Processing Record 48 of Set 15 | tigil
# Processing Record 49 of Set 15 | linfen
# Processing Record 50 of Set 15 | keti bandar
# Processing Record 1 of Set 16 | mapiripan
# Processing Record 2 of Set 16 | saint-augustin
# Processing Record 3 of Set 16 | yantzaza
# Processing Record 4 of Set 16 | podstepki
# Processing Record 5 of Set 16 | bokspits
# City not found. Skipping...
# Processing Record 6 of Set 16 | kysyl-syr
# Processing Record 7 of Set 16 | angra
# City not found. Skipping...
# Processing Record 8 of Set 16 | ust-kuyga
# Processing Record 9 of Set 16 | jacareacanga
# Processing Record 10 of Set 16 | eureka
# Processing Record 11 of Set 16 | carballo
# Processing Record 12 of Set 16 | corrales
# Processing Record 13 of Set 16 | baoying
# Processing Record 14 of Set 16 | college
# Processing Record 15 of Set 16 | baisha
# Processing Record 16 of Set 16 | deer lake
# Processing Record 17 of Set 16 | puri
# Processing Record 18 of Set 16 | mayo
# Processing Record 19 of Set 16 | port macquarie
# Processing Record 20 of Set 16 | severodvinsk
# Processing Record 21 of Set 16 | acuna
# City not found. Skipping...
# Processing Record 22 of Set 16 | palmas de monte alto
# Processing Record 23 of Set 16 | zharkent
# Processing Record 24 of Set 16 | loandjili
# Processing Record 25 of Set 16 | denpasar
# Processing Record 26 of Set 16 | shimoda
# Processing Record 27 of Set 16 | dingle
# Processing Record 28 of Set 16 | mwinilunga
# Processing Record 29 of Set 16 | coolum beach
# Processing Record 30 of Set 16 | bentong
# Processing Record 31 of Set 16 | palaiokhora
# City not found. Skipping...
# Processing Record 32 of Set 16 | yongan
# Processing Record 33 of Set 16 | majene
# Processing Record 34 of Set 16 | pimentel
# Processing Record 35 of Set 16 | jinxiang
# Processing Record 36 of Set 16 | gat
# Processing Record 37 of Set 16 | chato
# Processing Record 38 of Set 16 | yanam
# Processing Record 39 of Set 16 | petropavlovsk-kamchatskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 731

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kununurra -15.7667  128.7333    298.14        94          90
# 1      Souillac -20.5167   57.5167    299.36        78          40
# 2        Hobart -42.8794  147.3294    286.51        87         100
# 3        Mangai  -4.0500   19.5333    296.58        84          71
# 4   Kaisiadorys  54.8667   24.4500    274.24        86         100
# 5       Ushuaia -54.8000  -68.3000    281.94        81         100
# 6         Vaini -21.2000 -175.2000    300.38        81         100
# 7     Busselton -33.6500  115.3333    288.18        90         100
# 8  Kristinehamn  59.3098   14.1081    274.46        81         100
# 9        Atuona  -9.8000 -139.0333    299.33        76           3
#
#    Wind Speed Country                 Date Current Description
# 0        0.00      AU  2023-02-14 18:44:00     overcast clouds
# 1        4.12      MU  2023-02-14 18:44:01    scattered clouds
# 2        2.06      AU  2023-02-14 18:44:01     overcast clouds
# 3        0.36      CD  2023-02-14 18:44:02       moderate rain
# 4        2.11      LT  2023-02-14 18:44:02     overcast clouds
# 5        9.26      AR  2023-02-14 18:44:02       moderate rain
# 6        5.63      TO  2023-02-14 18:44:03          light rain
# 7        3.72      AU  2023-02-14 18:44:04     overcast clouds
# 8        4.25      SE  2023-02-14 18:44:04     overcast clouds
# 9        8.36      PF  2023-02-14 18:44:05          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Kununurra      AU -15.7667  128.7333    298.14        94          90
# 1      Souillac      MU -20.5167   57.5167    299.36        78          40
# 2        Hobart      AU -42.8794  147.3294    286.51        87         100
# 3        Mangai      CD  -4.0500   19.5333    296.58        84          71
# 4   Kaisiadorys      LT  54.8667   24.4500    274.24        86         100
# 5       Ushuaia      AR -54.8000  -68.3000    281.94        81         100
# 6         Vaini      TO -21.2000 -175.2000    300.38        81         100
# 7     Busselton      AU -33.6500  115.3333    288.18        90         100
# 8  Kristinehamn      SE  59.3098   14.1081    274.46        81         100
# 9        Atuona      PF  -9.8000 -139.0333    299.33        76           3
#
#    Wind Speed Current Description
# 0        0.00     overcast clouds
# 1        4.12    scattered clouds
# 2        2.06     overcast clouds
# 3        0.36       moderate rain
# 4        2.11     overcast clouds
# 5        9.26       moderate rain
# 6        5.63          light rain
# 7        3.72     overcast clouds
# 8        4.25     overcast clouds
# 9        8.36          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
